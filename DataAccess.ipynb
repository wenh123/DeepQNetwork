# %%
import yfinance as yf
import chainer.functions as F
import numpy as np

# %%
q_values = np.array([[32.521797, 32.058693, 30.90435]])
softmax_q_values = F.softmax(q_values).data
softmax_q_values
# Out:
# array([[0.54712624, 0.34432141, 0.10855235]])

# %%
q_values = np.array([[32.521797, 32.058693, 30.90435]])
softmax_q_values = F.softmax(q_values).data
#if step==0:print('\t'.join(map(str, [softmax_q_values])))
pact = np.random.choice(a=3,size=1, p=softmax_q_values.ravel())
amount = softmax_q_values.ravel()[pact]  # 使用 Softmax 正規化後的輸出選擇動作
print('\t'.join(map(str, [amount , pact])))
# Out:
# [0.54712624]	[0]

# %%
wti_oil = yf.download("CL=F", start='2001-01-01', end='2019-12-31')
print(wti_oil.head())  # 檢查數據
wti_oil.to_csv("2000_WTI.csv")
# 國際金價期貨
gold = yf.download("GC=F", start='2001-01-01', end='2019-12-31')
print(gold.head())  # 檢查數據
gold.to_csv("2000_GC=F.csv")

# %%
GSPC = yf.download("^GSPC", start='2001-01-01', end='2019-12-31')
print(GSPC.head())  # 檢查數據
GSPC.to_csv("2000_GSPC.csv")

# %%
import pandas as pd
wti_oil = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/WTI.txt')
GSPC = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/GSPC.txt')

df_gspc['Date'] = pd.to_datetime(df_gspc['Date'])
df_wti['Date'] = pd.to_datetime(df_wti['Date'])

df_gspc.set_index('Date', inplace=True)
df_wti.set_index('Date', inplace=True)


df_wti_renamed = df_wti.rename(columns=lambda x: 'Gold_' + x)


df_wti_resampled = df_wti_renamed.reindex(df_gspc.index)
df_wti_resampled = df_wti_resampled.interpolate(method='time')


df_combined = df_gspc.join(df_wti_resampled)


print(df_combined.head())


df_combined.to_csv("TEST.csv")
# Out:
# D:\Anaconda\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\Anaconda\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# D:\Anaconda\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11928/421435512.py in <module>
#       1 import pandas as pd
#       2 wti_oil = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/WTI.txt')
# ----> 3 GSPC = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/GSPC.txt')
#       4
#       5 df_gspc['Date'] = pd.to_datetime(df_gspc['Date'])
#
# D:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
from warnings import filterwarnings
from chainer import serializers
#print(check_output(["dir", "C:/Users/User/Documents/RL_"]).decode("utf8"))
filterwarnings(action='ignore', category=DeprecationWarning, message='`np.bool` is a deprecated alias')
filterwarnings(action='ignore', category=np.VisibleDeprecationWarning)  
# Any results you write to the current directory are saved as output.

import time
import copy
import numpy as np
import array as arr
import pandas as pd
import chainer
import chainer.functions as F
import chainer.links as L
import matplotlib.pyplot as plt
from plotly.offline import plot
import datetime
import plotly.graph_objects as go
#from plotly import tools
#from plotly.graph_objs import *
#from plotly.offline import init_notebook_mode, iplot, iplot_mpl
data = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/SPY.txt')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
print(data.index.min(), data.index.max())
data.head()
start_date = datetime.datetime(2001, 1, 1)
end_date = datetime.datetime(2019, 12, 31)
total_days = (end_date - start_date).days
train_days = int(total_days * 0.5)
test_start_date = start_date + datetime.timedelta(days=train_days)
date_split = test_start_date.date()
train = data[:date_split]
test = data[date_split:]
print("2001-2019的訓練期間:", start_date.date(), "到", test_start_date.date())
print("2001-2019的測試期間:", test_start_date.date(), "到", end_date.date())
total_days = (end_date - start_date).days
train_days = int(total_days * 0.5)
test_days = total_days - train_days

print("2001-2019的訓練天數:", train_days)
print("2001-2019的測試天數:", test_days)

start_date_2010 = datetime.datetime(2010, 1, 1)
end_date_2019 = datetime.datetime(2019, 12, 31)
total_days_2010_2019 = (end_date_2019 - start_date_2010).days
train_days_2010_2019 = int(total_days_2010_2019 * 0.9)
test_days_2010_2019 = total_days_2010_2019 - train_days_2010_2019

test_start_date_2010_2019 = start_date_2010 + datetime.timedelta(days=train_days_2010_2019)
train_end_date_2010_2019 = test_start_date_2010_2019 - datetime.timedelta(days=1)

print("2010-2019的訓練期間:", start_date_2010.date(), "到", train_end_date_2010_2019.date())
print("2010-2019的測試期間:", test_start_date_2010_2019.date(), "到", end_date_2019.date())

print("2010-2019的訓練天數:", train_days_2010_2019)
print("2010-2019的測試天數:", test_days_2010_2019)
# Out:
# D:\Anaconda\lib\site-packages\pkg_resources\__init__.py:123: PkgResourcesDeprecationWarning: 4.0.0-unsupported is an invalid version and will not be supported in a future release
#   warnings.warn(
# 2001-01-02 00:00:00 2019-12-30 00:00:00
# 2001-2019的訓練期間: 2001-01-01 到 2010-07-02
# 2001-2019的測試期間: 2010-07-02 到 2019-12-31
# 2001-2019的訓練天數: 3469
# 2001-2019的測試天數: 3469
# 2010-2019的訓練期間: 2010-01-01 到 2018-12-29
# 2010-2019的測試期間: 2018-12-30 到 2019-12-31
# 2010-2019的訓練天數: 3285
# 2010-2019的測試天數: 366

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
from warnings import filterwarnings
from chainer import serializers
#print(check_output(["dir", "C:/Users/User/Documents/RL_"]).decode("utf8"))
filterwarnings(action='ignore', category=DeprecationWarning, message='`np.bool` is a deprecated alias')
filterwarnings(action='ignore', category=np.VisibleDeprecationWarning)  
# Any results you write to the current directory are saved as output.

import time
import copy
import numpy as np
import array as arr
import pandas as pd
import chainer
import chainer.functions as F
import chainer.links as L
import matplotlib.pyplot as plt
from plotly.offline import plot
import datetime
import plotly.graph_objects as go
#from plotly import tools
#from plotly.graph_objs import *
#from plotly.offline import init_notebook_mode, iplot, iplot_mpl
data = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/SPY.txt')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
print(data.index.min(), data.index.max())
data.head()
start_date = datetime.datetime(2010, 1, 1)
end_date = datetime.datetime(2019, 12, 31)
total_days = (end_date - start_date).days
train_days = int(total_days * 0.9)
test_start_date = start_date + datetime.timedelta(days=train_days)
date_split = test_start_date.date()
train = data[:date_split]
test = data[date_split:]
# Out:
# 2001-01-02 00:00:00 2019-12-30 00:00:00

# %%
def plot_train_test(train, test, date_split):
    # 创建图形
    train_candle = go.Candlestick(x=train.index, open=train['Open'], high=train['High'], low=train['Low'], close=train['Close'], name='Train')
    test_candle = go.Candlestick(x=test.index, open=test['Open'], high=test['High'], low=test['Low'], close=test['Close'], name='Test')
    
    fig = go.Figure(data=[train_candle, test_candle])
    
    # 添加分割线
    fig.add_shape(
        type="line",
        x0=date_split, y0=min(min(train['Low']), min(test['Low'])),
        x1=date_split, y1=max(max(train['High']), max(test['High'])),
        line=dict(color="Black", width=4)
    )
    
    # 添加注释
    fig.add_annotation(
        x=date_split, y=max(max(train['High']), max(test['High'])), ax=0, ay=-40,  # Adjust the arrow position
        xref='x', yref='y',
        showarrow=True, arrowhead=1,
        text="Start of Test Data",
        font=dict(size=14, color="black"),  # Increase font size and specify color
        bgcolor="white",  # Add background color for better readability
        bordercolor="black",
        borderwidth=2
    )
    
    # 更新布局
    fig.update_layout(
        title='Train and Test Data Visualization',
        xaxis_title='Date',
        yaxis_title='Price',
        title_font=dict(size=16),  # Increase title font size
        xaxis=dict(
            title_font=dict(size=14),  # Increase x-axis title font size
            tickfont=dict(size=12)  # Increase x-axis tick font size
        ),
        yaxis=dict(
            title_font=dict(size=14),  # Increase y-axis title font size
            tickfont=dict(size=12)  # Increase y-axis tick font size
        )
    )
    # 显示图形
    fig.show()

# 调用函数
plot_train_test(train, test, date_split)
# Out:
# <div>                            <div id="b6d087c9-a522-4d6b-aa95-86062e155577" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6d087c9-a522-4d6b-aa95-86062e155577")) {                    Plotly.newPlot(                        "b6d087c9-a522-4d6b-aa95-86062e155577",                        [{"close":[1283.27001953125,1347.56005859375,1333.3399658203125,1298.3499755859375,1295.8599853515625,1300.800048828125,1313.27001953125,1326.8199462890625,1318.550048828125,1326.6500244140625,1329.469970703125,1347.969970703125,1342.5400390625,1342.9000244140625,1360.4000244140625,1364.300048828125,1357.510009765625,1354.949951171875,1364.1700439453125,1373.72998046875,1366.010009765625,1373.469970703125,1349.469970703125,1354.31005859375,1352.260009765625,1340.8
# ...

# %%
USER_6640b62862ef32046cd7d63a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11928/3569113327.py in <module>
# ----> 1 USER_6640b62862ef32046cd7d63a
#
# NameError: name 'USER_6640b62862ef32046cd7d63a' is not defined

# %%
.qaz889029123
