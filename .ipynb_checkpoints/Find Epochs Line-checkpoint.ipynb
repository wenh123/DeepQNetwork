# %%
import pandas as pd
import numpy as np
import copy
import time
import chainer
import chainer.functions as F
import chainer.links as L
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import pickle

# 定义环境类
class Environment1:
    def __init__(self, data, history_t=90):
        self.data = data
        self.history_t = history_t
        self.reset()
        
    def reset(self):
        self.t = 0
        self.done = False
        self.profits = 10000 # 初始资金
        self.count = 0 # 张数
        self.positions = []
        self.position_value = 0
        self.brok_rate = 0.0009
        self.tbrokerage = 0
        self.history = [0 for _ in range(self.history_t)]
        return [self.position_value] + self.history # obs
    
    def step(self, act, amount=1):
        reward = 0
        
        # act = 0: stay, 1: buy, 2: sell
        if act == 1:
            if self.profits != 0:
                count = amount * self.profits / self.data.iloc[self.t, :]['Close']
                if count > 1:
                    self.count = count
                    self.profits = 0
                    self.tbrokerage = self.brok_rate * self.data.iloc[self.t, :]['Close']
                    self.positions.append(self.data.iloc[self.t, :]['Close'])
        elif act == 2: # sell
            if len(self.positions) == 0:
                reward = -1
            else:
                if self.count != 0:
                    profits = 0
                    for p in self.positions:
                        profits += ((self.count * self.data.iloc[self.t, :]['Close']) - p)
                    reward += profits - self.tbrokerage
                    self.count = 0
                    self.tbrokerage = 0
                    self.profits += profits
                    self.positions = []
        
        # set next time
        self.t += 1
        self.position_value = 0
        for p in self.positions:
            self.position_value += (self.data.iloc[self.t, :]['Close'] - p)
        self.history.pop(0)
        self.history.append(self.data.iloc[self.t, :]['Close'] - self.data.iloc[(self.t-1), :]['Close'])
        
        # clipping reward
        if reward > 0:
            reward = 1
        elif reward < 0:
            reward = -1
        
        return [self.position_value] + self.history, reward, self.done # obs, reward, done

# 定义Q_Network类
class Q_Network(chainer.Chain):
    def __init__(self, input_size, hidden_size, output_size):
        super(Q_Network, self).__init__(
            fc1 = L.Linear(input_size, hidden_size),
            fc2 = L.Linear(hidden_size, hidden_size),
            fc3 = L.Linear(hidden_size, output_size)
        )

    def __call__(self, x):
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        y = self.fc3(h)
        return y

    def reset(self):
        self.zerograds()

# 修改 train_dqn 函数以接受 epoch_num 参数
def train_dqn(env, Q=None, total_step=0, epoch_num=300):
    if Q is None:
        Q = Q_Network(input_size=env.history_t+1, hidden_size=100, output_size=3)
    Q_ast = copy.deepcopy(Q)
    optimizer = chainer.optimizers.Adam()
    optimizer.setup(Q)

    step_max = len(env.data)-1
    memory_size = 200
    batch_size = 20
    epsilon = 1.0
    epsilon_decrease = 1e-3
    epsilon_min = 0.1
    start_reduce_epsilon = 200
    train_freq = 10
    update_q_freq = 20
    gamma = 0.97
    show_log_freq = 1
    confidence_threshold_buy = 0.1
    confidence_threshold_sell = 0.8

    memory = []
    total_rewards = []
    total_losses = []
    start = time.time()

    
    for epoch in range(epoch_num):

        pobs = env.reset()
        step = 0
        done = False
        total_reward = 0
        total_loss = 0
        RandAct = 0
        NRandAct = 0
        while not done and step < step_max:
            # select act
            pact = np.random.randint(3)
            amount = 0.25
            if np.random.rand() > epsilon:
                q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
                softmax_q_values = F.softmax(q_values).data
                amount = softmax_q_values.ravel()[pact]
                pact = np.random.choice(3, p=softmax_q_values.ravel())
                # act = 0: stay, 1: buy, 2: sell
                if pact == 2 and amount < confidence_threshold_sell:
                    pact = 0
                if pact == 1 and amount < confidence_threshold_buy:
                    pact = 0
                NRandAct += 1
            else:
                RandAct += 1
                if pact == 0:
                    amount = 0.5

            # act
            obs, reward, done = env.step(pact, amount)

            # add memory
            memory.append((pobs, pact, reward, obs, done))
            if len(memory) > memory_size:
                memory.pop(0)

            # train or update q
            if len(memory) == memory_size:
                if total_step % train_freq == 0:
                    shuffled_memory = np.random.permutation(memory)
                    memory_idx = range(len(shuffled_memory))
                    for i in memory_idx[::batch_size]:
                        batch = np.array(shuffled_memory[i:i+batch_size])
                        b_pobs = np.array(batch[:, 0].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_pact = np.array(batch[:, 1].tolist(), dtype=np.int32)
                        b_reward = np.array(batch[:, 2].tolist(), dtype=np.int32)
                        b_obs = np.array(batch[:, 3].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)

                        q = Q(b_pobs)
                        maxq = np.max(Q_ast(b_obs).data, axis=1)
                        target = copy.deepcopy(q.data)
                        for j in range(batch_size):
                            target[j, b_pact[j]] = b_reward[j] + gamma * maxq[j] * (not b_done[j])
                        Q.reset()
                        loss = F.mean_squared_error(q, target)
                        total_loss += loss.data
                        loss.backward()
                        optimizer.update()

                if total_step % update_q_freq == 0:
                    Q_ast = copy.deepcopy(Q)

            # epsilon
            if epsilon > epsilon_min and total_step > start_reduce_epsilon:
                epsilon -= epsilon_decrease

            # next step
            total_reward += reward
            pobs = obs
            step += 1
            total_step += 1

        total_rewards.append(total_reward)
        total_losses.append(total_loss)

        if (epoch+1) % show_log_freq == 0:
            log_reward = sum(total_rewards[((epoch+1)-show_log_freq):])/show_log_freq
            log_loss = sum(total_losses[((epoch+1)-show_log_freq):])/show_log_freq
            log_profits = env.profits
            if len(env.positions) != 0:
                for i in range(0, len(env.positions)):
                    log_profits += env.count * env.data.iloc[env.t, :]['Close']
            else:
                log_profits = env.profits
            elapsed_time = time.time() - start
            
            print('\t'.join(map(str, [epoch+1, log_profits, env.count, env.position_value])))
            start = time.time()
            
    return Q, total_step, total_losses, total_rewards

def test_dqn(test_env, Q, confidence_threshold_buy=0.1, confidence_threshold_sell=0.8):
    # 重置環境
    pobs = test_env.reset()
    test_env.profits = 10000  # 重置初始資金
    test_acts = []
    test_rewards = []

    for _ in range(len(test_env.data)-1):
        # 使用DQN產生行動的機率分布
        q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
        softmax_q_values = F.softmax(q_values).data
        pact = np.random.choice(3, p=softmax_q_values.ravel())
        
        # 根據設定的閾值判斷是否執行買入或賣出
        amount = softmax_q_values.ravel()[pact]
        if pact == 2 and amount < confidence_threshold_sell:
            pact = 0
        elif pact == 1 and amount < confidence_threshold_buy:
            pact = 0
        
        # 執行行動
        obs, reward, done = test_env.step(pact, amount)
        test_acts.append(pact)
        test_rewards.append(reward)
        pobs = obs

    # 測試最後一天，將所有持股賣出
    for idx in range(len(test_env.positions)):
        stock_price = test_env.data.iloc[-1, :]['Close']
        sell_price = test_env.positions[idx]
        count = test_env.count
        test_env.profits += sell_price * count

    test_env.positions = []
    test_env.count = []

    # 計算最終收益
    test_profits = test_env.profits
    return test_acts, test_rewards, test_profits

# 加载数据
data = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/GSPC2010-2019_both.txt')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')

# 将数据分成训练和测试集
date_split = '2018-12-31'
train_data = data[:date_split]
test_data = data[date_split:]

# 创建用于训练和测试的环境实例
train_env = Environment1(train_data)
test_env = Environment1(test_data)

# 存储每个epoch_num的最终利润
epoch_nums = range(30, 50)
final_profits = []
Q = None  # 初始Q网络为空
total_step = 0
print('\t'.join(map(str, ['epoch', 'profit', '          ', 'buy', 'sell', 'hold'])))
for epoch_num in epoch_nums:
    # 使用当前的epoch_num训练模型，如果Q为空，则从头开始训练
    Q, total_step, total_losses, total_rewards = train_dqn(train_env, Q=Q, total_step=total_step, epoch_num=1 if Q else epoch_num)
    
    # 保存Q网络
    with open(f'Q_network_epoch_{epoch_num}.pkl', 'wb') as f:
        pickle.dump(Q, f)
    
    # 绘制结果并收集最终利润
    test_acts, test_rewards, test_profits = test_dqn(test_env, Q)
    final_profits.append(test_profits)

# 绘制最终利润与epoch_nums的关系图
plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, final_profits, label='Final Profits')
plt.xlabel('Epoch Number')
plt.ylabel('Final Profits')
plt.title('Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# epoch	profit	          	buy	sell	hold
# C:\Users\User\AppData\Local\Temp/ipykernel_36372/3863404793.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   shuffled_memory = np.random.permutation(memory)
# C:\Users\User\AppData\Local\Temp/ipykernel_36372/3863404793.py:167: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)
# 1	-0.00472944141915832	0	0
# 2	188.74927571708986	0	0
# 3	106.6690255752444	0	0
# 4	234.5535816709653	0	0
# 5	306.4725525017311	0	0
# 6	-15.62121136319638	0	0
# 7	1368.6933600164061	0	0
# 8	125.792391449957	0	0
# 9	1287.1825544911303	0	0
# 10	1268.689150995514	0	0
# 11	1436.1149301103897	0	0
# 12	-31.338579430670507	0	0
# 13	888.4156386903892	0	0
# 14	51.83215125597326	0	0
# 15	1145.6745781071836	0	0
# 16	1112.1229290190204	0	0
# 17	507.13816015285465	0	0
# 18	130.45446399200205	0	0
# 19	252.70286186455246	0	0
# 20	250.636777665384	0	0
# 21	238.47069228475266	0	0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36372/3863404793.py in <module>
#     272 for epoch_num in epoch_nums:
#     273     # 使用当前的epoch_num训练模型，如果Q为空，则从头开始训练
# --> 274     Q, total_step, total_losses, total_rewards = train_dqn(train_env, Q=Q, total_step=total_step, epoch_num=1 if Q else epoch_num)
#     275
#     276     # 保存Q网络
#
# ~\AppData\Local\Temp/ipykernel_36372/3863404793.py in train_dqn(env, Q, total_step, epoch_num)
#     167                         b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)
#     168
# --> 169                         q = Q(b_pobs)
#     170                         maxq = np.max(Q_ast(b_obs).data, axis=1)
#     171                         target = copy.deepcopy(q.data)
#
# ~\AppData\Local\Temp/ipykernel_36372/3863404793.py in __call__(self, x)
#      81
#      82     def __call__(self, x):
# ---> 83         h = F.relu(self.fc1(x))
#      84         h = F.relu(self.fc2(h))
#      85         y = self.fc3(h)
#
# D:\Anaconda\lib\site-packages\chainer\link.py in __call__(self, *args, **kwargs)
#     285             # forward is implemented in the child classes
#     286             forward = self.forward  # type: ignore
# --> 287         out = forward(*args, **kwargs)
#     288
#     289         # Call forward_postprocess hook
#
# D:\Anaconda\lib\site-packages\chainer\links\connection\linear.py in forward(self, x, n_batch_axes)
#     181             in_size = utils.size_of_shape(x.shape[n_batch_axes:])
#     182             self._initialize_params(in_size)
# --> 183         return linear.linear(x, self.W, self.b, n_batch_axes=n_batch_axes)
#
# D:\Anaconda\lib\site-packages\chainer\functions\connection\linear.py in linear(x, W, b, n_batch_axes)
#     306         args = x, W, b
#     307
# --> 308     y, = LinearFunction().apply(args)
#     309     if n_batch_axes > 1:
#     310         y = y.reshape(batch_shape + (-1,))
#
# D:\Anaconda\lib\site-packages\chainer\function_node.py in apply(self, inputs)
#     332             else:
#     333                 # In normal case, simply run the forward method.
# --> 334                 outputs = self.forward(in_data)
#     335
#     336         # Check for output array types
#
# D:\Anaconda\lib\site-packages\chainer\functions\connection\linear.py in forward(self, inputs)
#     113         # of output arrays during execution of the static schedule
#     114         # because it would break the model.
# --> 115         self.static_linear_no_bias(xp, x.dtype == W.dtype, inputs=[x, W],
#     116                                    outputs=[y])
#     117         if len(inputs) == 3:
#
# D:\Anaconda\lib\site-packages\chainer\graph_optimizations\static_graph_utilities.py in wrapped_func(*args, **kwargs)
#     184                         instance.schedule_func = schedule_function
#     185             else:
# --> 186                 ret = func(*args, **kwargs)
#     187             return ret
#     188         return wrapped_func
#
# D:\Anaconda\lib\site-packages\chainer\functions\connection\linear.py in static_linear_no_bias(self, xp, optimized, inputs, outputs)
#      54             # have the same dtype. Otherwise, the output type (for y)
#      55             # may not be as expected (i.e., not the same dtype as x).
# ---> 56             xp.dot(x, W.T, out=y)
#      57         else:
#      58             y[:] = x.dot(W.T).astype(x.dtype, copy=False)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import chainer
import chainer.functions as F
import chainer.links as L
import copy
import time
import pandas as pd
import datetime

class Q_Network(chainer.Chain):
    def __init__(self, input_size, hidden_size, output_size):
        super(Q_Network, self).__init__(
            fc1 = L.Linear(input_size, hidden_size),
            fc2 = L.Linear(hidden_size, hidden_size),
            fc3 = L.Linear(hidden_size, output_size)
        )
    def __call__(self, x):
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        y = self.fc3(h)
        return y
    def reset(self):
        self.zerograds()

class Environment1:
    def __init__(self, data, history_t=90):
        self.data = data
        self.history_t = history_t
        self.reset()
        
    def reset(self):
        self.t = 0
        self.done = False
        self.profits = 10000
        self.count = []
        self.positions = []
        self.position_value = 0
        self.brok_rate = 0.0009
        self.max_trade_percent = 0.8
        self.tbrokerage = 0
        self.history = [0 for _ in range(self.history_t)]
        self.Act0 = 0
        self.Act1 = 0
        self.Act2 = 0
        self.RW_p = 0
        self.RW_n = 0
        self.RW_p_v = 0
        self.RW_n_v = 0
        return [self.position_value] + self.history
    
    def step(self, act, amount):
        if self.t >= len(self.data) - 1:
            self.done = True
            return [self.position_value] + self.history, 0, self.done

        reward = 0
        if act == 1:
            if self.profits != 0:
                max_trade_amount = self.profits * self.max_trade_percent
                stock_price = self.data.iloc[self.t, :]['Close']
                count = max_trade_amount / stock_price
                buyin = stock_price * count
                self.profits -= buyin
                self.positions.append(stock_price)
                self.count.append(count)
                self.Act1 += 1
        elif act == 2:
            if len(self.positions) > 0:
                sell_ratio = self.determine_sell_ratio(amount)
                num_positions_to_sell = int(len(self.positions) * sell_ratio)
                for i in range(num_positions_to_sell):
                    sell_price = self.data.iloc[self.t, :]['Close']
                    buy_price = self.positions[i]
                    count = self.count[i]
                    abs_num = (sell_price - buy_price) * count
                    if abs_num > 0:
                        self.RW_p += 1
                        self.RW_p_v += abs_num
                    else:
                        self.RW_n += 1
                        self.RW_n_v += abs(abs_num)
                    reward += sell_price * count
                    self.profits += sell_price * count
                self.positions = self.positions[num_positions_to_sell:]
                self.count = self.count[num_positions_to_sell:]
                self.Act2 += 1    
        else:
            self.Act0 += 1
        
        self.t += 1
        if self.t >= len(self.data):
            self.done = True
        self.position_value = 0
        for p in self.positions:
            self.position_value += (self.data.iloc[self.t, :]['Close'] - p)
        self.history.pop(0)
        self.history.append(self.data.iloc[self.t, :]['Close'] - self.data.iloc[(self.t-1), :]['Close'])
        
        if reward > 0:
            reward = 1
        elif reward < 0:
            reward = -1
        
        return [self.position_value] + self.history, reward, self.done
    
    def determine_sell_ratio(self, signal_strength):
        thresholds = [0.2, 0.5, 0.8]
        ratios = [0.25, 0.5, 0.75]
        for i, threshold in enumerate(thresholds):
            if signal_strength < threshold:
                return ratios[i]
        return ratios[0]

def train_dqn(env, Q, epoch_num=1):
    Q_ast = copy.deepcopy(Q)
    optimizer = chainer.optimizers.Adam()
    optimizer.setup(Q)

    step_max = len(env.data)-1
    memory_size = 200
    batch_size = 20
    epsilon = 1.0
    epsilon_decrease = 1e-3
    epsilon_min = 0.1
    start_reduce_epsilon = 200
    train_freq = 10
    update_q_freq = 20
    gamma = 0.97
    show_log_freq = 1
    confidence_threshold_buy = 0.1
    confidence_threshold_sell = 0.8
    memory = []
    total_step = 0
    total_rewards = []
    total_losses = []
    start = time.time()
    
    for epoch in range(epoch_num):
        pobs = env.reset()
        step = 0
        done = False
        total_reward = 0
        total_loss = 0
        RandAct = 0
        NRandAct = 0
        while not done and step < step_max:
            pact = np.random.randint(3)
            amount = 0.25
            if np.random.rand() > epsilon:
                q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
                softmax_q_values = F.softmax(q_values).data
                amount = softmax_q_values.ravel()[pact]
                pact = np.random.choice(3, p=softmax_q_values.ravel())
                if pact == 2:
                    if amount < confidence_threshold_sell:
                        pact = 0
                if pact == 1:
                    if amount < confidence_threshold_buy:
                        pact = 0
                NRandAct+=1
            else:
                RandAct+=1
                if pact==0: amount = 0.5
            obs, reward, done = env.step(pact,amount)
            memory.append((pobs, pact, reward, obs, done))
            if len(memory) > memory_size:
                memory.pop(0)
            if len(memory) == memory_size:
                if total_step % train_freq == 0:
                    shuffled_memory = np.random.permutation(memory)
                    memory_idx = range(len(shuffled_memory))
                    for i in memory_idx[::batch_size]:
                        batch = np.array(shuffled_memory[i:i+batch_size])
                        b_pobs = np.array(batch[:, 0].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_pact = np.array(batch[:, 1].tolist(), dtype=np.int32)
                        b_reward = np.array(batch[:, 2].tolist(), dtype=np.int32)
                        b_obs = np.array(batch[:, 3].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)
                        q = Q(b_pobs)
                        maxq = np.max(Q_ast(b_obs).data, axis=1)
                        target = copy.deepcopy(q.data)
                        for j in range(batch_size):
                            target[j, b_pact[j]] = b_reward[j]+gamma*maxq[j]*(not b_done[j])
                        Q.reset()
                        loss = F.mean_squared_error(q, target)
                        total_loss += loss.data
                        loss.backward()
                        optimizer.update()
                if total_step % update_q_freq == 0:
                    Q_ast = copy.deepcopy(Q)
            if epsilon > epsilon_min and total_step > start_reduce_epsilon:
                epsilon -= epsilon_decrease
            total_reward += reward
            pobs = obs
            step += 1
            total_step += 1
        total_rewards.append(total_reward)
        total_losses.append(total_loss)
        if (epoch+1) % show_log_freq == 0:
            log_reward = sum(total_rewards[((epoch+1)-show_log_freq):])/show_log_freq
            log_loss = sum(total_losses[((epoch+1)-show_log_freq):])/show_log_freq
            log_profits = env.profits
            if isinstance(env.count, list) and len(env.count) != 0:
                for i in range(len(env.positions)):
                    log_profits += env.count[i] * env.data.iloc[env.t, :]['Close']
            else:
                log_profits = env.profits
            elapsed_time = time.time()-start
            print(f"Training Epoch {epoch+1} - Profit: {log_profits}")
            start = time.time()       
    return Q, total_losses, total_rewards

def test_dqn(test_env, Q, confidence_threshold_buy=0.1, confidence_threshold_sell=0.8):
    pobs = test_env.reset()
    test_env.profits = 10000
    test_acts = []
    test_rewards = []
    estimated_total_assets = [test_env.profits]

    while not test_env.done:
        q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
        softmax_q_values = F.softmax(q_values).data
        pact = np.random.choice(3, p=softmax_q_values.ravel())
        amount = softmax_q_values.ravel()[pact]
        if pact == 2 and amount < confidence_threshold_sell:
            pact = 0
        elif pact == 1 and amount < confidence_threshold_buy:
            pact = 0
        obs, reward, done = test_env.step(pact, amount)
        test_acts.append(pact)
        test_rewards.append(reward)
        pobs = obs
        stock_value = sum(c * test_env.data.iloc[test_env.t]['Close'] for c in test_env.count)
        total_assets = test_env.profits + stock_value
        estimated_total_assets.append(total_assets)

    final_profits = total_assets
    return test_acts, test_rewards, final_profits

data = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/SPY_Both.txt')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')

start_date_2010 = datetime.datetime(2010, 1, 1)
end_date_2019 = datetime.datetime(2019, 12, 31)
total_days_2010_2019 = (end_date_2019 - start_date_2010).days
train_days_2010_2019 = int(total_days_2010_2019 * 0.9)
test_days_2010_2019 = total_days_2010_2019 - train_days_2010_2019

test_start_date_2010_2019 = start_date_2010 + datetime.timedelta(days=train_days_2010_2019)
train_end_date_2010_2019 = test_start_date_2010_2019 - datetime.timedelta(days=1)

print("2010-2019的訓練期間:", start_date_2010.date(), "到", train_end_date_2010_2019.date())
print("2010-2019的測試期間:", test_start_date_2010_2019.date(), "到", end_date_2019.date())

print("2010-2019的訓練天數:", train_days_2010_2019)
print("2010-2019的測試天數:", test_days_2010_2019)

train = data[start_date_2010.date():train_end_date_2010_2019.date()]
test = data[test_start_date_2010_2019.date():end_date_2019.date()]
train_env = Environment1(train)
test_env = Environment1(test)

epoch_nums = range(30, 300)
final_profits = []
print('\t'.join(map(str, ['epoch', 'profit'])))
Q = Q_Network(input_size=train_env.history_t+1, hidden_size=100, output_size=3)  # 初始Q网络

# 预训练30个epoch
Q, total_losses, total_rewards = train_dqn(train_env, Q, epoch_num=29)
chainer.serializers.save_npz(f'Q_network_epoch_{29}.npz', Q)
print(f"Pre-training complete for Epoch 29")

# 从31个epoch开始继续训练和测试
for epoch_num in epoch_nums:
    Q, total_losses, total_rewards = train_dqn(train_env, Q, epoch_num=1)
    chainer.serializers.save_npz(f'Q_network_epoch_{epoch_num}.npz', Q)
    print(f"Training complete for Epoch {epoch_num}")
    _, _, test_profits = test_dqn(test_env, Q)
    final_profits.append(test_profits)
    print(f"Epoch {epoch_num} - Final Profits: {test_profits}")

plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, final_profits, label='Final Profits')
plt.xlabel('Epoch Number')
plt.ylabel('Final Profits')
plt.title('Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2010-2019的訓練期間: 2010-01-01 到 2018-12-29
# 2010-2019的測試期間: 2018-12-30 到 2019-12-31
# 2010-2019的訓練天數: 3285
# 2010-2019的測試天數: 366
# epoch	profit
# C:\Users\User\AppData\Local\Temp/ipykernel_36372/2599834455.py:172: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   shuffled_memory = np.random.permutation(memory)
# C:\Users\User\AppData\Local\Temp/ipykernel_36372/2599834455.py:180: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)
# Training Epoch 1 - Profit: 15539.656397823604
# Training Epoch 2 - Profit: 21922.1522094335
# Training Epoch 3 - Profit: 19567.53657474514
# Training Epoch 4 - Profit: 23425.160176214245
# Training Epoch 5 - Profit: 16674.356418473897
# Training Epoch 6 - Profit: 23241.842766305675
# Training Epoch 7 - Profit: 19642.44227318433
# Training Epoch 8 - Profit: 18361.18492754092
# Training Epoch 9 - Profit: 17861.2595752225
# Training Epoch 10 - Profit: 23981.41288075225
# Training Epoch 11 - Profit: 16447.889114860627
# Training Epoch 12 - Profit: 21522.782901312443
# Training Epoch 13 - Profit: 16440.846861408674
# Training Epoch 14 - Profit: 16230.488291982356
# Training Epoch 15 - Profit: 19368.06904584238
# Training Epoch 16 - Profit: 22095.818053488914
# Training Epoch 17 - Profit: 20928.284684589766
# Training Epoch 18 - Profit: 21332.546437658544
# Training Epoch 19 - Profit: 20362.414590253236
# Training Epoch 20 - Profit: 20768.47593462579
# Training Epoch 21 - Profit: 25888.133779736552
# Training Epoch 22 - Profit: 17177.34002217391
# Training Epoch 23 - Profit: 17971.215797616023
# Training Epoch 24 - Profit: 21647.383327978805
# Training Epoch 25 - Profit: 18279.719548443296
# Training Epoch 26 - Profit: 21353.244352877264
# Training Epoch 27 - Profit: 17328.231496212546
# Training Epoch 28 - Profit: 17664.545807624367
# Training Epoch 29 - Profit: 18553.69822670597
# Pre-training complete for Epoch 29
# Training Epoch 1 - Profit: 17801.233651722974
# Training complete for Epoch 30
# Epoch 30 - Final Profits: 13045.606128791747
# Training Epoch 1 - Profit: 21300.44679568334
# Training complete for Epoch 31
# Epoch 31 - Final Profits: 12500.166905515774
# Training Epoch 1 - Profit: 17235.241019683734
# Training complete for Epoch 32
# Epoch 32 - Final Profits: 12524.92796036456
# Training Epoch 1 - Profit: 17718.619134522876
# Training complete for Epoch 33
# Epoch 33 - Final Profits: 12829.573101348347
# Epoch 287 - Final Profits: 12387.37333763892
# Training Epoch 1 - Profit: 17750.1857486963
# Training complete for Epoch 288
# Epoch 288 - Final Profits: 12837.259052176587
# Training Epoch 1 - Profit: 14437.11727371596
# Training complete for Epoch 289
# Epoch 289 - Final Profits: 12671.416544495856
# Training Epoch 1 - Profit: 19757.817050901685
# Training complete for Epoch 290
# Epoch 290 - Final Profits: 12602.802649287247
# Training Epoch 1 - Profit: 19579.852097628143
# Training complete for Epoch 291
# Epoch 291 - Final Profits: 12892.394213091442
# Training Epoch 1 - Profit: 23645.8866524053
# Training complete for Epoch 292
# Epoch 292 - Final Profits: 12842.146407598988
# Training Epoch 1 - Profit: 17268.864694215175
# Training complete for Epoch 293
# Epoch 293 - Final Profits: 12848.625033258711
# Training Epoch 1 - Profit: 19245.647294956245
# Training complete for Epoch 294
# Epoch 294 - Final Profits: 12373.273062909015
# Training Epoch 1 - Profit: 18465.316416688634
# Training complete for Epoch 295
# Epoch 295 - Final Profits: 12247.595651125117
# Training Epoch 1 - Profit: 20412.064895196505
# Training complete for Epoch 296
# Epoch 296 - Final Profits: 11814.838203129306
# Training Epoch 1 - Profit: 24190.824391654693
# Training complete for Epoch 297
# Epoch 297 - Final Profits: 12440.174521884608
# Training Epoch 1 - Profit: 18409.78271647524
# Training complete for Epoch 298
# Epoch 298 - Final Profits: 12630.796857251456
# Training Epoch 1 - Profit: 21941.319555687383
# Training complete for Epoch 299
# Epoch 299 - Final Profits: 12762.474500334323

# %%
import numpy as np
import matplotlib.pyplot as plt

# 假设 final_profits 已经存在
# final_profits = ...

# 设置窗口大小
window_size = 10  # 可根据需要调整窗口大小

# 计算移动平均
moving_average = np.convolve(final_profits, np.ones(window_size) / window_size, mode='valid')

# 确定绘图的 x 轴范围
epoch_nums_for_avg = range(30, 30 + len(moving_average))

# 绘制图表
plt.figure(figsize=(10, 6))
plt.plot(range(30, 30 + len(final_profits)), final_profits, label='Final Profits')
plt.plot(epoch_nums_for_avg, moving_average, label='Moving Average', color='red')
plt.xlabel('Epoch Number')
plt.ylabel('Final Profits')
plt.title('Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 設置窗口大小
window_size = 10

# 計算移動平均
moving_average = np.convolve(final_profits, np.ones(window_size) / window_size, mode='valid')

# 確定繪圖的 x 軸範圍
epoch_nums_for_avg = range(30, 30 + len(moving_average))

# 繪制圖表
plt.figure(figsize=(10, 6))
plt.plot(range(30, 30 + len(final_profits)), final_profits, label='Final Profits')
plt.plot(epoch_nums_for_avg, moving_average, label='Moving Average', color='red')
plt.axvline(x=50, color='green', linestyle='--', label='Under-Trained Epoch (50)')
plt.axvline(x=200, color='blue', linestyle='--', label='Well-Trained Epoch (200)')
plt.xlabel('Epoch Number')
plt.ylabel('Final Profits')
plt.title('Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import chainer
import chainer.functions as F
import chainer.links as L
import copy
import time
import pandas as pd
import datetime

class Q_Network(chainer.Chain):
    def __init__(self, input_size, hidden_size, output_size):
        super(Q_Network, self).__init__(
            fc1 = L.Linear(input_size, hidden_size),
            fc2 = L.Linear(hidden_size, hidden_size),
            fc3 = L.Linear(hidden_size, output_size)
        )
    def __call__(self, x):
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        y = self.fc3(h)
        return y
    def reset(self):
        self.zerograds()

class Environment1:
    def __init__(self, data, history_t=90):
        self.data = data
        self.history_t = history_t
        self.reset()
        
    def reset(self):
        self.t = 0
        self.done = False
        self.profits = 10000
        self.count = []
        self.positions = []
        self.position_value = 0
        self.brok_rate = 0.0009
        self.max_trade_percent = 0.8
        self.tbrokerage = 0
        self.history = [0 for _ in range(self.history_t)]
        self.Act0 = 0
        self.Act1 = 0
        self.Act2 = 0
        self.RW_p = 0
        self.RW_n = 0
        self.RW_p_v = 0
        self.RW_n_v = 0
        return [self.position_value] + self.history
    
    def step(self, act, amount):
        if self.t >= len(self.data) - 1:
            self.done = True
            return [self.position_value] + self.history, 0, self.done

        reward = 0
        if act == 1:
            if self.profits != 0:
                max_trade_amount = self.profits * self.max_trade_percent
                stock_price = self.data.iloc[self.t, :]['Close']
                count = max_trade_amount / stock_price
                buyin = stock_price * count
                self.profits -= buyin
                self.positions.append(stock_price)
                self.count.append(count)
                self.Act1 += 1
        elif act == 2:
            if len(self.positions) > 0:
                sell_ratio = self.determine_sell_ratio(amount)
                num_positions_to_sell = int(len(self.positions) * sell_ratio)
                for i in range(num_positions_to_sell):
                    sell_price = self.data.iloc[self.t, :]['Close']
                    buy_price = self.positions[i]
                    count = self.count[i]
                    abs_num = (sell_price - buy_price) * count
                    if abs_num > 0:
                        self.RW_p += 1
                        self.RW_p_v += abs_num
                    else:
                        self.RW_n += 1
                        self.RW_n_v += abs(abs_num)
                    reward += sell_price * count
                    self.profits += sell_price * count
                self.positions = self.positions[num_positions_to_sell:]
                self.count = self.count[num_positions_to_sell:]
                self.Act2 += 1    
        else:
            self.Act0 += 1
        
        self.t += 1
        if self.t >= len(self.data):
            self.done = True
        self.position_value = 0
        for p in self.positions:
            self.position_value += (self.data.iloc[self.t, :]['Close'] - p)
        self.history.pop(0)
        self.history.append(self.data.iloc[self.t, :]['Close'] - self.data.iloc[(self.t-1), :]['Close'])
        
        if reward > 0:
            reward = 1
        elif reward < 0:
            reward = -1
        
        return [self.position_value] + self.history, reward, self.done
    
    def determine_sell_ratio(self, signal_strength):
        thresholds = [0.2, 0.5, 0.8]
        ratios = [0.25, 0.5, 0.75]
        for i, threshold in enumerate(thresholds):
            if signal_strength < threshold:
                return ratios[i]
        return ratios[0]

def train_dqn(env, Q, epoch_num=1):
    Q_ast = copy.deepcopy(Q)
    optimizer = chainer.optimizers.Adam()
    optimizer.setup(Q)

    step_max = len(env.data)-1
    memory_size = 200
    batch_size = 20
    epsilon = 1.0
    epsilon_decrease = 1e-3
    epsilon_min = 0.1
    start_reduce_epsilon = 200
    train_freq = 10
    update_q_freq = 20
    gamma = 0.97
    show_log_freq = 1
    confidence_threshold_buy = 0.1
    confidence_threshold_sell = 0.8
    memory = []
    total_step = 0
    total_rewards = []
    total_losses = []
    start = time.time()
    
    for epoch in range(epoch_num):
        pobs = env.reset()
        step = 0
        done = False
        total_reward = 0
        total_loss = 0
        RandAct = 0
        NRandAct = 0
        while not done and step < step_max:
            pact = np.random.randint(3)
            amount = 0.25
            if np.random.rand() > epsilon:
                q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
                softmax_q_values = F.softmax(q_values).data
                amount = softmax_q_values.ravel()[pact]
                pact = np.random.choice(3, p=softmax_q_values.ravel())
                if pact == 2:
                    if amount < confidence_threshold_sell:
                        pact = 0
                if pact == 1:
                    if amount < confidence_threshold_buy:
                        pact = 0
                NRandAct+=1
            else:
                RandAct+=1
                if pact==0: amount = 0.5
            obs, reward, done = env.step(pact,amount)
            memory.append((pobs, pact, reward, obs, done))
            if len(memory) > memory_size:
                memory.pop(0)
            if len(memory) == memory_size:
                if total_step % train_freq == 0:
                    shuffled_memory = np.random.permutation(memory)
                    memory_idx = range(len(shuffled_memory))
                    for i in memory_idx[::batch_size]:
                        batch = np.array(shuffled_memory[i:i+batch_size])
                        b_pobs = np.array(batch[:, 0].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_pact = np.array(batch[:, 1].tolist(), dtype=np.int32)
                        b_reward = np.array(batch[:, 2].tolist(), dtype=np.int32)
                        b_obs = np.array(batch[:, 3].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)
                        q = Q(b_pobs)
                        maxq = np.max(Q_ast(b_obs).data, axis=1)
                        target = copy.deepcopy(q.data)
                        for j in range(batch_size):
                            target[j, b_pact[j]] = b_reward[j]+gamma*maxq[j]*(not b_done[j])
                        Q.reset()
                        loss = F.mean_squared_error(q, target)
                        total_loss += loss.data
                        loss.backward()
                        optimizer.update()
                if total_step % update_q_freq == 0:
                    Q_ast = copy.deepcopy(Q)
            if epsilon > epsilon_min and total_step > start_reduce_epsilon:
                epsilon -= epsilon_decrease
            total_reward += reward
            pobs = obs
            step += 1
            total_step += 1
        total_rewards.append(total_reward)
        total_losses.append(total_loss)
        if (epoch+1) % show_log_freq == 0:
            log_reward = sum(total_rewards[((epoch+1)-show_log_freq):])/show_log_freq
            log_loss = sum(total_losses[((epoch+1)-show_log_freq):])/show_log_freq
            log_profits = env.profits
            if isinstance(env.count, list) and len(env.count) != 0:
                for i in range(len(env.positions)):
                    log_profits += env.count[i] * env.data.iloc[env.t, :]['Close']
            else:
                log_profits = env.profits
            elapsed_time = time.time()-start
            print(f"Training Epoch {epoch+1} - Profit: {log_profits}")
            start = time.time()       
    return Q, total_losses, total_rewards

def test_dqn(test_env, Q, confidence_threshold_buy=0.1, confidence_threshold_sell=0.8):
    pobs = test_env.reset()
    test_env.profits = 10000
    test_acts = []
    test_rewards = []
    estimated_total_assets = [test_env.profits]

    while not test_env.done:
        q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
        softmax_q_values = F.softmax(q_values).data
        pact = np.random.choice(3, p=softmax_q_values.ravel())
        amount = softmax_q_values.ravel()[pact]
        if pact == 2 and amount < confidence_threshold_sell:
            pact = 0
        elif pact == 1 and amount < confidence_threshold_buy:
            pact = 0
        obs, reward, done = test_env.step(pact, amount)
        test_acts.append(pact)
        test_rewards.append(reward)
        pobs = obs
        stock_value = sum(c * test_env.data.iloc[test_env.t]['Close'] for c in test_env.count)
        total_assets = test_env.profits + stock_value
        estimated_total_assets.append(total_assets)

    final_profits = total_assets
    return test_acts, test_rewards, final_profits

data = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/SPY_Both.txt')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')

start_date_2010 = datetime.datetime(2010, 1, 1)
end_date_2019 = datetime.datetime(2019, 12, 31)
total_days_2010_2019 = (end_date_2019 - start_date_2010).days
train_days_2010_2019 = int(total_days_2010_2019 * 0.9)
test_days_2010_2019 = total_days_2010_2019 - train_days_2010_2019

test_start_date_2010_2019 = start_date_2010 + datetime.timedelta(days=train_days_2010_2019)
train_end_date_2010_2019 = test_start_date_2010_2019 - datetime.timedelta(days=1)

print("2010-2019的訓練期間:", start_date_2010.date(), "到", train_end_date_2010_2019.date())
print("2010-2019的測試期間:", test_start_date_2010_2019.date(), "到", end_date_2019.date())

print("2010-2019的訓練天數:", train_days_2010_2019)
print("2010-2019的測試天數:", test_days_2010_2019)

train = data[start_date_2010.date():train_end_date_2010_2019.date()]
test = data[test_start_date_2010_2019.date():end_date_2019.date()]
train_env = Environment1(train)
test_env = Environment1(test)

epoch_nums = range(30, 300)
final_profits = []
print('\t'.join(map(str, ['epoch', 'profit'])))
Q = Q_Network(input_size=train_env.history_t+1, hidden_size=100, output_size=3)  # 初始Q网络

# 预训练30个epoch
Q, total_losses, total_rewards = train_dqn(train_env, Q, epoch_num=29)
chainer.serializers.save_npz(f'Q_network_epoch_{29}.npz', Q)
print(f"Pre-training complete for Epoch 29")

# 从31个epoch开始继续训练和测试
for epoch_num in epoch_nums:
    Q, total_losses, total_rewards = train_dqn(train_env, Q, epoch_num=1)
    chainer.serializers.save_npz(f'Q_network_epoch_{epoch_num}.npz', Q)
    print(f"Training complete for Epoch {epoch_num}")
    
    # 进行10次测试并计算平均值
    test_profits_list = []
    for _ in range(10):
        _, _, test_profits = test_dqn(test_env, Q)
        test_profits_list.append(test_profits)
    avg_test_profits = np.mean(test_profits_list)
    
    final_profits.append(avg_test_profits)
    print(f"Epoch {epoch_num} - Average Final Profits: {avg_test_profits}")

plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, final_profits, label='Average Final Profits')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Average Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 
# Training Epoch 1 - Profit: 18357.684876191626
# Training complete for Epoch 286
# Epoch 286 - Average Final Profits: 12626.049579951974
# Training Epoch 1 - Profit: 18166.522303660775
# Training complete for Epoch 287
# Epoch 287 - Average Final Profits: 12783.499737788088
# Training Epoch 1 - Profit: 20833.792384126547
# Training complete for Epoch 288
# Epoch 288 - Average Final Profits: 12586.405351787125
# Training Epoch 1 - Profit: 16288.875804255245
# Training complete for Epoch 289
# Epoch 289 - Average Final Profits: 11544.718702946437
# Training Epoch 1 - Profit: 23374.54923315066
# Training complete for Epoch 290
# Epoch 290 - Average Final Profits: 12762.133951306187
# Training Epoch 1 - Profit: 22963.823320691066
# Training complete for Epoch 291
# Epoch 291 - Average Final Profits: 12022.345238499856
# Training Epoch 1 - Profit: 23099.036267080894
# Training complete for Epoch 292
# Epoch 292 - Average Final Profits: 12830.383010448631
# Training Epoch 1 - Profit: 23097.924167291232
# Training complete for Epoch 293
# Epoch 293 - Average Final Profits: 12620.646596232813
# Training Epoch 1 - Profit: 20227.251511371735
# Training complete for Epoch 294
# Epoch 294 - Average Final Profits: 12860.853309355904
# Training Epoch 1 - Profit: 18210.86806595326
# Training complete for Epoch 295
# Epoch 295 - Average Final Profits: 11925.610886833467
# Training Epoch 1 - Profit: 16404.115693499843
# Training complete for Epoch 296
# Epoch 296 - Average Final Profits: 12735.728969547254
# Training Epoch 1 - Profit: 18507.384377623483
# Training complete for Epoch 297
# Epoch 297 - Average Final Profits: 12693.456075417118
# Training Epoch 1 - Profit: 15955.37106578367
# Training complete for Epoch 298
# Epoch 298 - Average Final Profits: 11951.133171192754
# Training Epoch 1 - Profit: 16157.225199520299
# Training complete for Epoch 299
# Epoch 299 - Average Final Profits: 12807.789888748624

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import chainer
import chainer.functions as F
import chainer.links as L
import copy
import time
import pandas as pd
import datetime

class Q_Network(chainer.Chain):
    def __init__(self, input_size, hidden_size, output_size):
        super(Q_Network, self).__init__(
            fc1 = L.Linear(input_size, hidden_size),
            fc2 = L.Linear(hidden_size, hidden_size),
            fc3 = L.Linear(hidden_size, output_size)
        )
    def __call__(self, x):
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        y = self.fc3(h)
        return y
    def reset(self):
        self.zerograds()

class Environment1:
    def __init__(self, data, history_t=90):
        self.data = data
        self.history_t = history_t
        self.reset()
        
    def reset(self):
        self.t = 0
        self.done = False
        self.profits = 10000
        self.count = []
        self.positions = []
        self.position_value = 0
        self.brok_rate = 0.0009
        self.max_trade_percent = 0.8
        self.tbrokerage = 0
        self.history = [0 for _ in range(self.history_t)]
        self.Act0 = 0
        self.Act1 = 0
        self.Act2 = 0
        self.RW_p = 0
        self.RW_n = 0
        self.RW_p_v = 0
        self.RW_n_v = 0
        return [self.position_value] + self.history
    
    def step(self, act, amount):
        if self.t >= len(self.data) - 1:
            self.done = True
            return [self.position_value] + self.history, 0, self.done

        reward = 0
        if act == 1:
            if self.profits != 0:
                max_trade_amount = self.profits * self.max_trade_percent
                stock_price = self.data.iloc[self.t, :]['Close']
                count = max_trade_amount / stock_price
                buyin = stock_price * count
                self.profits -= buyin
                self.positions.append(stock_price)
                self.count.append(count)
                self.Act1 += 1
        elif act == 2:
            if len(self.positions) > 0:
                sell_ratio = self.determine_sell_ratio(amount)
                num_positions_to_sell = int(len(self.positions) * sell_ratio)
                for i in range(num_positions_to_sell):
                    sell_price = self.data.iloc[self.t, :]['Close']
                    buy_price = self.positions[i]
                    count = self.count[i]
                    abs_num = (sell_price - buy_price) * count
                    if abs_num > 0:
                        self.RW_p += 1
                        self.RW_p_v += abs_num
                    else:
                        self.RW_n += 1
                        self.RW_n_v += abs(abs_num)
                    reward += sell_price * count
                    self.profits += sell_price * count
                self.positions = self.positions[num_positions_to_sell:]
                self.count = self.count[num_positions_to_sell:]
                self.Act2 += 1    
        else:
            self.Act0 += 1
        
        self.t += 1
        if self.t >= len(self.data):
            self.done = True
        self.position_value = 0
        for p in self.positions:
            self.position_value += (self.data.iloc[self.t, :]['Close'] - p)
        self.history.pop(0)
        self.history.append(self.data.iloc[self.t, :]['Close'] - self.data.iloc[(self.t-1), :]['Close'])
        
        if reward > 0:
            reward = 1
        elif reward < 0:
            reward = -1
        
        return [self.position_value] + self.history, reward, self.done
    
    def determine_sell_ratio(self, signal_strength):
        thresholds = [0.2, 0.5, 0.8]
        ratios = [0.25, 0.5, 0.75]
        for i, threshold in enumerate(thresholds):
            if signal_strength < threshold:
                return ratios[i]
        return ratios[0]

def train_dqn(env, Q, epoch_num=1):
    Q_ast = copy.deepcopy(Q)
    optimizer = chainer.optimizers.Adam()
    optimizer.setup(Q)

    step_max = len(env.data)-1
    memory_size = 200
    batch_size = 20
    epsilon = 1.0
    epsilon_decrease = 1e-3
    epsilon_min = 0.1
    start_reduce_epsilon = 200
    train_freq = 10
    update_q_freq = 20
    gamma = 0.97
    show_log_freq = 1
    confidence_threshold_buy = 0.11803540036662069
    confidence_threshold_sell = 0.5689542195973996
    memory = []
    total_step = 0
    total_rewards = []
    total_losses = []
    start = time.time()
    
    for epoch in range(epoch_num):
        pobs = env.reset()
        step = 0
        done = False
        total_reward = 0
        total_loss = 0
        RandAct = 0
        NRandAct = 0
        while not done and step < step_max:
            pact = np.random.randint(3)
            amount = 0.25
            if np.random.rand() > epsilon:
                q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
                softmax_q_values = F.softmax(q_values).data
                amount = softmax_q_values.ravel()[pact]
                pact = np.random.choice(3, p=softmax_q_values.ravel())
                if pact == 2:
                    if amount < confidence_threshold_sell:
                        pact = 0
                if pact == 1:
                    if amount < confidence_threshold_buy:
                        pact = 0
                NRandAct+=1
            else:
                RandAct+=1
                if pact==0: amount = 0.5
            obs, reward, done = env.step(pact,amount)
            memory.append((pobs, pact, reward, obs, done))
            if len(memory) > memory_size:
                memory.pop(0)
            if len(memory) == memory_size:
                if total_step % train_freq == 0:
                    shuffled_memory = np.random.permutation(memory)
                    memory_idx = range(len(shuffled_memory))
                    for i in memory_idx[::batch_size]:
                        batch = np.array(shuffled_memory[i:i+batch_size])
                        b_pobs = np.array(batch[:, 0].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_pact = np.array(batch[:, 1].tolist(), dtype=np.int32)
                        b_reward = np.array(batch[:, 2].tolist(), dtype=np.int32)
                        b_obs = np.array(batch[:, 3].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)
                        q = Q(b_pobs)
                        maxq = np.max(Q_ast(b_obs).data, axis=1)
                        target = copy.deepcopy(q.data)
                        for j in range(batch_size):
                            target[j, b_pact[j]] = b_reward[j]+gamma*maxq[j]*(not b_done[j])
                        Q.reset()
                        loss = F.mean_squared_error(q, target)
                        total_loss += loss.data
                        loss.backward()
                        optimizer.update()
                if total_step % update_q_freq == 0:
                    Q_ast = copy.deepcopy(Q)
            if epsilon > epsilon_min and total_step > start_reduce_epsilon:
                epsilon -= epsilon_decrease
            total_reward += reward
            pobs = obs
            step += 1
            total_step += 1
        total_rewards.append(total_reward)
        total_losses.append(total_loss)
        if (epoch+1) % show_log_freq == 0:
            log_reward = sum(total_rewards[((epoch+1)-show_log_freq):])/show_log_freq
            log_loss = sum(total_losses[((epoch+1)-show_log_freq):])/show_log_freq
            log_profits = env.profits
            if isinstance(env.count, list) and len(env.count) != 0:
                for i in range(len(env.positions)):
                    log_profits += env.count[i] * env.data.iloc[env.t, :]['Close']
            else:
                log_profits = env.profits
            elapsed_time = time.time()-start
            print(f"Training Epoch {epoch+1} - Profit: {log_profits}")
            start = time.time()       
    return Q, total_losses, total_rewards

def test_dqn(test_env, Q, confidence_threshold_buy=0.1, confidence_threshold_sell=0.8):
    pobs = test_env.reset()
    test_env.profits = 10000
    test_acts = []
    test_rewards = []
    estimated_total_assets = [test_env.profits]

    while not test_env.done:
        q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
        softmax_q_values = F.softmax(q_values).data
        pact = np.random.choice(3, p=softmax_q_values.ravel())
        amount = softmax_q_values.ravel()[pact]
        if pact == 2 and amount < confidence_threshold_sell:
            pact = 0
        elif pact == 1 and amount < confidence_threshold_buy:
            pact = 0
        obs, reward, done = test_env.step(pact, amount)
        test_acts.append(pact)
        test_rewards.append(reward)
        pobs = obs
        stock_value = sum(c * test_env.data.iloc[test_env.t]['Close'] for c in test_env.count)
        total_assets = test_env.profits + stock_value
        estimated_total_assets.append(total_assets)

    final_profits = total_assets
    return test_acts, test_rewards, final_profits

data = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/SPY_Both.txt')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')

start_date_2010 = datetime.datetime(2010, 1, 1)
end_date_2019 = datetime.datetime(2019, 12, 31)
total_days_2010_2019 = (end_date_2019 - start_date_2010).days
train_days_2010_2019 = int(total_days_2010_2019 * 0.9)
test_days_2010_2019 = total_days_2010_2019 - train_days_2010_2019

test_start_date_2010_2019 = start_date_2010 + datetime.timedelta(days=train_days_2010_2019)
train_end_date_2010_2019 = test_start_date_2010_2019 - datetime.timedelta(days=1)

print("2010-2019的訓練期間:", start_date_2010.date(), "到", train_end_date_2010_2019.date())
print("2010-2019的測試期間:", test_start_date_2010_2019.date(), "到", end_date_2019.date())

print("2010-2019的訓練天數:", train_days_2010_2019)
print("2010-2019的測試天數:", test_days_2010_2019)

train = data[start_date_2010.date():train_end_date_2010_2019.date()]
test = data[test_start_date_2010_2019.date():end_date_2019.date()]
train_env = Environment1(train)
test_env = Environment1(test)

epoch_nums = range(30, 300)
final_profits = []
print('\t'.join(map(str, ['epoch', 'profit'])))
Q = Q_Network(input_size=train_env.history_t+1, hidden_size=100, output_size=3)  # 初始Q网络

# 预训练30个epoch
Q, total_losses, total_rewards = train_dqn(train_env, Q, epoch_num=29)
chainer.serializers.save_npz(f'Q_network_epoch_{29}.npz', Q)
print(f"Pre-training complete for Epoch 29")

# 从31个epoch开始继续训练和测试
for epoch_num in epoch_nums:
    Q, total_losses, total_rewards = train_dqn(train_env, Q, epoch_num=1)
    chainer.serializers.save_npz(f'Q_network_epoch_{epoch_num}.npz', Q)
    print(f"Training complete for Epoch {epoch_num}")
    
    # 进行10次测试并计算平均值
    test_profits_list = []
    for _ in range(100):
        _, _, test_profits = test_dqn(test_env, Q)
        test_profits_list.append(test_profits)
    avg_test_profits = np.mean(test_profits_list)
    
    final_profits.append(avg_test_profits)
    print(f"Epoch {epoch_num} - Average Final Profits: {avg_test_profits}")

plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, final_profits, label='Average Final Profits')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Average Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2010-2019的訓練期間: 2010-01-01 到 2018-12-29
# 2010-2019的測試期間: 2018-12-30 到 2019-12-31
# 2010-2019的訓練天數: 3285
# 2010-2019的測試天數: 366
# epoch	profit
# C:\Users\User\AppData\Local\Temp/ipykernel_36372/4048082698.py:172: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   shuffled_memory = np.random.permutation(memory)
# C:\Users\User\AppData\Local\Temp/ipykernel_36372/4048082698.py:180: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)
# Training Epoch 1 - Profit: 17638.26993489138
# Training Epoch 2 - Profit: 21291.136275870955
# Training Epoch 3 - Profit: 20529.812901983467
# Training Epoch 4 - Profit: 19283.531720650266
# Training Epoch 5 - Profit: 17008.914436758383
# Training Epoch 6 - Profit: 17354.24216723416
# Training Epoch 7 - Profit: 20333.381153077335
# Training Epoch 8 - Profit: 20973.234835238098
# Training Epoch 9 - Profit: 18009.269710138393
# Training Epoch 10 - Profit: 22072.51758186894
# Training Epoch 11 - Profit: 19726.466697826723
# Training Epoch 12 - Profit: 19549.24625672691
# Training Epoch 13 - Profit: 21242.394560715078
# Training Epoch 14 - Profit: 19295.64826930243
# Training Epoch 15 - Profit: 19946.969765767855
# Training Epoch 16 - Profit: 21506.891584216966
# Training Epoch 17 - Profit: 18971.552732692617
# Training Epoch 18 - Profit: 21876.961653775954
# Training Epoch 19 - Profit: 21527.62497632533
# Training Epoch 20 - Profit: 27173.54265797655
# Training Epoch 21 - Profit: 21828.057606384038
# Training Epoch 22 - Profit: 15309.946828236496
# Training Epoch 23 - Profit: 19527.92114980837
# Training Epoch 24 - Profit: 17769.82156229079
# Training Epoch 25 - Profit: 19647.24886102511
# Training Epoch 26 - Profit: 21942.248441430285
# Training Epoch 27 - Profit: 19575.85730279225
# Training Epoch 28 - Profit: 20004.336555923695
# Training Epoch 29 - Profit: 22478.74924436403
# Pre-training complete for Epoch 29
# Training Epoch 1 - Profit: 21796.13953855235
# Training complete for Epoch 30
# Epoch 30 - Average Final Profits: 12612.913932786681
# Training Epoch 1 - Profit: 22196.054112994138
# Training complete for Epoch 31
# Epoch 31 - Average Final Profits: 12665.654365220862
# Training Epoch 1 - Profit: 18080.50355563881
# Training complete for Epoch 32
# Epoch 32 - Average Final Profits: 12795.83583640766
# Training Epoch 1 - Profit: 17880.414052038774
# Training complete for Epoch 33
# Epoch 33 - Average Final Profits: 12768.88398601642
# Training Epoch 1 - Profit: 18477.19782111032
# Training complete for Epoch 34
# Epoch 34 - Average Final Profits: 12712.853503456196
# Training Epoch 1 - Profit: 14814.073168858999
# Training complete for Epoch 35
# Epoch 35 - Average Final Profits: 12662.661706552506
# Training Epoch 1 - Profit: 18240.48308828396
# Training complete for Epoch 36
# Epoch 36 - Average Final Profits: 12746.955782448724
# Training Epoch 1 - Profit: 20463.584722023894
# Training complete for Epoch 37
# Epoch 37 - Average Final Profits: 12721.352712842288
# Training Epoch 1 - Profit: 20497.400210707237
# Training complete for Epoch 38
# Epoch 38 - Average Final Profits: 12749.170311993284
# Training Epoch 1 - Profit: 19368.230206912234
# Training complete for Epoch 39
# Epoch 39 - Average Final Profits: 12734.375455484778
# Training Epoch 1 - Profit: 16148.826082997683
# Training complete for Epoch 40
# Epoch 40 - Average Final Profits: 12761.165415525951
# Training Epoch 1 - Profit: 21554.124662034938
# Training complete for Epoch 41
# Epoch 41 - Average Final Profits: 12708.592544463236
# Training Epoch 1 - Profit: 21121.14047376766
# Training complete for Epoch 42
# Epoch 42 - Average Final Profits: 12762.870397162222
# Training Epoch 1 - Profit: 16503.562129493668
# Training complete for Epoch 43
# Epoch 43 - Average Final Profits: 12794.079131685232
# Training Epoch 1 - Profit: 20503.236459475498
# Training complete for Epoch 44
# Epoch 44 - Average Final Profits: 12715.695813900744
# Training Epoch 1 - Profit: 19428.41118815188
# Training complete for Epoch 45
# Epoch 45 - Average Final Profits: 12732.396853773644
# Training Epoch 1 - Profit: 22215.032389449894
# Training complete for Epoch 46
# Epoch 46 - Average Final Profits: 10988.62169540077
# Training Epoch 1 - Profit: 16632.29684284351
# Training complete for Epoch 47
# Epoch 47 - Average Final Profits: 12793.355991363287
# Training Epoch 1 - Profit: 13780.548965430115
# Training complete for Epoch 195
# Epoch 195 - Average Final Profits: 12771.234505256221
# Training Epoch 1 - Profit: 18549.271929718474
# Training complete for Epoch 196
# Epoch 196 - Average Final Profits: 11820.856046009781
# Training Epoch 1 - Profit: 16278.645630432979
# Training complete for Epoch 197
# Epoch 197 - Average Final Profits: 12801.079609157752
# Training Epoch 1 - Profit: 18948.300931134963
# Training complete for Epoch 198
# Epoch 198 - Average Final Profits: 12613.671277584785
# Training Epoch 1 - Profit: 17620.78994147699
# Training complete for Epoch 199
# Epoch 199 - Average Final Profits: 12744.86577125895
# Training Epoch 1 - Profit: 21409.371655819537
# Training complete for Epoch 200
# Epoch 200 - Average Final Profits: 12746.383471221012
# Training Epoch 1 - Profit: 18942.055044030796
# Training complete for Epoch 201
# Epoch 201 - Average Final Profits: 12197.74772318012
# Training Epoch 1 - Profit: 15078.739142399363
# Training complete for Epoch 202
# Epoch 202 - Average Final Profits: 12524.862009929044
# Training Epoch 1 - Profit: 23120.261863900116
# Training complete for Epoch 203
# Epoch 203 - Average Final Profits: 12671.734661611503
# Training Epoch 1 - Profit: 14677.849786298053
# Training complete for Epoch 204
# Epoch 204 - Average Final Profits: 12786.230146737276
# Training Epoch 1 - Profit: 16514.428924064974
# Training complete for Epoch 205
# Epoch 205 - Average Final Profits: 12638.64271768036
# Training Epoch 1 - Profit: 15237.520744183515
# Training complete for Epoch 206
# Epoch 206 - Average Final Profits: 11959.226202343405
# Training Epoch 1 - Profit: 16036.618110538362
# Training complete for Epoch 207
# Epoch 207 - Average Final Profits: 12712.990377262715
# Training Epoch 1 - Profit: 19695.88348463877
# Training complete for Epoch 208
# Epoch 208 - Average Final Profits: 12665.616588101147
# Training Epoch 1 - Profit: 19058.07594468061
# Training complete for Epoch 209
# Epoch 209 - Average Final Profits: 12232.708681066946
# Training Epoch 1 - Profit: 21362.47407151848
# Training complete for Epoch 210
# Epoch 210 - Average Final Profits: 12728.367522519216
# Training Epoch 1 - Profit: 17346.020629813804
# Training complete for Epoch 211
# Epoch 211 - Average Final Profits: 11847.59936253175
# Training Epoch 1 - Profit: 17042.523422638915
# Training complete for Epoch 212
# Epoch 212 - Average Final Profits: 12553.488934938785
# Training Epoch 1 - Profit: 19780.00986853875
# Training complete for Epoch 213
# Epoch 213 - Average Final Profits: 12764.503045779262
# Training Epoch 1 - Profit: 19217.725364732407
# Training complete for Epoch 214
# Epoch 214 - Average Final Profits: 12643.78984010594
# Training Epoch 1 - Profit: 15550.205596269137
# Training complete for Epoch 215
# Epoch 215 - Average Final Profits: 12872.567014720164
# Training Epoch 1 - Profit: 18255.126085710974
# Training complete for Epoch 216
# Epoch 216 - Average Final Profits: 12717.387791357052
# Training Epoch 1 - Profit: 18386.646626258498
# Training complete for Epoch 217
# Epoch 217 - Average Final Profits: 12739.12558430391
# Training Epoch 1 - Profit: 17116.196708163385
# Training complete for Epoch 218
# Epoch 218 - Average Final Profits: 12634.497735004756
# Training Epoch 1 - Profit: 18500.696770440973
# Training complete for Epoch 219
# Epoch 219 - Average Final Profits: 12530.96678901841
# Training complete for Epoch 293
# Epoch 293 - Average Final Profits: 12585.551751504718
# Training Epoch 1 - Profit: 15032.85101996022
# Training complete for Epoch 294
# Epoch 294 - Average Final Profits: 12857.923999141629
# Training Epoch 1 - Profit: 18921.757943803957
# Training complete for Epoch 295
# Epoch 295 - Average Final Profits: 11972.781205253686
# Training Epoch 1 - Profit: 20486.610622189586
# Training complete for Epoch 296
# Epoch 296 - Average Final Profits: 11518.379981624268
# Training Epoch 1 - Profit: 18312.224212051122
# Training complete for Epoch 297
# Epoch 297 - Average Final Profits: 12801.153940302775
# Training Epoch 1 - Profit: 14117.399660427658
# Training complete for Epoch 298
# Epoch 298 - Average Final Profits: 12714.743446275237
# Training Epoch 1 - Profit: 15396.208650971525
# Training complete for Epoch 299
# Epoch 299 - Average Final Profits: 12820.288235479478

# %%
import numpy as np

np.save('final_profits.npy', final_profits)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 模擬從保存的變數讀取final_profits
final_profits = np.load('final_profits.npy')  # 修改為final_profits變數的存放路徑
epoch_nums = range(30, 300)

# 使用移動平均來平滑數據
window_size = 10  # 可以根據需要調整窗口大小
smoothed_profits = np.convolve(final_profits, np.ones(window_size)/window_size, mode='valid')

# 繪製平滑曲線
plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, final_profits, label='Average Final Profits')
plt.plot(epoch_nums[window_size-1:], smoothed_profits, label='Smoothed Profits', color='red')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Average Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import medfilt

# 模擬從保存的變數讀取final_profits
final_profits = np.load('final_profits.npy')  # 修改為final_profits變數的存放路徑
epoch_nums = range(30, 300)

# 使用中值濾波器來移除異常值
filtered_profits = medfilt(final_profits, kernel_size=5)

# 使用移動平均來平滑數據
window_size = 10  # 可以根據需要調整窗口大小
smoothed_profits = np.convolve(filtered_profits, np.ones(window_size)/window_size, mode='valid')

# 繪製平滑曲線
plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, final_profits, label='Average Final Profits')
plt.plot(epoch_nums, filtered_profits, label='Filtered Profits', color='green')
plt.plot(epoch_nums[window_size-1:], smoothed_profits, label='Smoothed Profits', color='red')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Average Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import medfilt

# 加載final_profits數據
final_profits = np.load('final_profits.npy')  # 修改為final_profits變數的存放路徑
epoch_nums = range(30, 300)

# 使用中值濾波器來移除異常值
filtered_profits = medfilt(final_profits, kernel_size=5)

# 使用移動平均來平滑數據
window_size = 10  # 可以根據需要調整窗口大小
smoothed_profits = np.convolve(filtered_profits, np.ones(window_size)/window_size, mode='valid')

# 調整epoch_nums的長度以匹配smoothed_profits的長度
adjusted_epoch_nums = epoch_nums[window_size-1:window_size-1+len(smoothed_profits)]

# 繪製平滑曲線
plt.figure(figsize=(10, 6))

plt.plot(adjusted_epoch_nums, smoothed_profits, label='Smoothed Profits', color='red')

# 在epochs=50和200處畫一條垂直線
plt.axvline(x=50, color='green', linestyle='--', label='Under-Trained Epoch (50)')
plt.axvline(x=200, color='blue', linestyle='--', label='Well-Trained Epoch (200)')

plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Average Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 加載final_profits數據
final_profits = np.load('final_profits.npy')
epoch_nums = range(30, 300)

# 設置忽略值的閾值
threshold = 12000
filtered_profits = np.array([x if x >= threshold else np.nan for x in final_profits])

# 使用移動平均來平滑數據
window_size = 10  # 可以根據需要調整窗口大小
smoothed_profits = np.convolve(filtered_profits[np.logical_not(np.isnan(filtered_profits))], 
                               np.ones(window_size)/window_size, mode='valid')

# 調整epoch_nums的長度以匹配smoothed_profits的長度
adjusted_epoch_nums = epoch_nums[window_size-1:window_size-1+len(smoothed_profits)]

# 繪製平滑曲線
plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, filtered_profits, label='Filtered Profits', color='green')
plt.plot(adjusted_epoch_nums, smoothed_profits, label='Smoothed Profits', color='red')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Average Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt

# 加載final_profits數據
final_profits = np.load('final_profits.npy')
epoch_nums = np.arange(30, 300)

# 設置忽略值的閾值
threshold = 12000
filtered_profits = np.array([x if x >= threshold else np.nan for x in final_profits])

# 填充NaN值以進行平滑處理
filtered_profits = np.where(np.isnan(filtered_profits), np.nanmean(filtered_profits), filtered_profits)

# 定義低通濾波器函數
def butter_lowpass_filter(data, cutoff, fs, order=5):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

# 設置低通濾波器參數
cutoff = 0.05  # 調整截止頻率以獲得所需的平滑度
fs = 1.0  # 采樣頻率

# 應用低通濾波器
smoothed_profits = butter_lowpass_filter(filtered_profits, cutoff, fs)

# 繪製平滑曲線
plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, smoothed_profits, color='red')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Smoothed Final Profits vs Epoch Number')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt

# 加載final_profits數據
final_profits = np.load('final_profits.npy')
epoch_nums = np.arange(30, 300)

# 設置忽略值的閾值
threshold = 12000
filtered_profits = np.array([x if x >= threshold else np.nan for x in final_profits])

# 填充NaN值以進行平滑處理
filtered_profits = np.where(np.isnan(filtered_profits), np.nanmean(filtered_profits), filtered_profits)

# 定義低通濾波器函數
def butter_lowpass_filter(data, cutoff, fs, order=5):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

# 設置低通濾波器參數
cutoff = 0.05  # 調整截止頻率以獲得所需的平滑度
fs = 1.0  # 采樣頻率

# 應用低通濾波器
smoothed_profits = butter_lowpass_filter(filtered_profits, cutoff, fs)

# 繪製平滑曲線，縮小Y軸範圍以減少波動看起來的幅度
plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, smoothed_profits, color='red')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Smoothed Final Profits vs Epoch Number')
plt.yticks([10000, 11000, 12000, 13000])  # 設置Y軸刻度
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt

# 加載final_profits數據
final_profits = np.load('final_profits.npy')
epoch_nums = np.arange(30, 300)

# 定義低通濾波器函數
def butter_lowpass_filter(data, cutoff, fs, order=5):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

# 設置低通濾波器參數
cutoff = 0.05  # 調整截止頻率以獲得所需的平滑度
fs = 1.0  # 采樣頻率

# 應用低通濾波器
smoothed_profits = butter_lowpass_filter(final_profits, cutoff, fs)

# 繪製平滑曲線，縮小Y軸範圍以減少波動看起來的幅度
plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, smoothed_profits, color='red')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Smoothed Final Profits vs Epoch Number')
plt.yticks([12500, 12000, 11500, 11000])  # 設置Y軸刻度
plt.grid(True)
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import chainer
import chainer.functions as F
import chainer.links as L
import copy
import time
import pandas as pd
import datetime

class Q_Network(chainer.Chain):
    def __init__(self, input_size, hidden_size, output_size):
        super(Q_Network, self).__init__(
            fc1 = L.Linear(input_size, hidden_size),
            fc2 = L.Linear(hidden_size, hidden_size),
            fc3 = L.Linear(hidden_size, output_size)
        )
    def __call__(self, x):
        h = F.relu(self.fc1(x))
        h = F.relu(self.fc2(h))
        y = self.fc3(h)
        return y
    def reset(self):
        self.zerograds()

class Environment1:
    def __init__(self, data, history_t=90):
        self.data = data
        self.history_t = history_t
        self.reset()
        
    def reset(self):
        self.t = 0
        self.done = False
        self.profits = 10000
        self.count = []
        self.positions = []
        self.position_value = 0
        self.brok_rate = 0.0009
        self.max_trade_percent = 0.8
        self.tbrokerage = 0
        self.history = [0 for _ in range(self.history_t)]
        self.Act0 = 0
        self.Act1 = 0
        self.Act2 = 0
        self.RW_p = 0
        self.RW_n = 0
        self.RW_p_v = 0
        self.RW_n_v = 0
        return [self.position_value] + self.history
    
    def step(self, act, amount):
        if self.t >= len(self.data) - 1:
            self.done = True
            return [self.position_value] + self.history, 0, self.done

        reward = 0
        if act == 1:
            if self.profits != 0:
                max_trade_amount = self.profits * self.max_trade_percent
                stock_price = self.data.iloc[self.t, :]['Close']
                count = max_trade_amount / stock_price
                buyin = stock_price * count
                self.profits -= buyin
                self.positions.append(stock_price)
                self.count.append(count)
                self.Act1 += 1
        elif act == 2:
            if len(self.positions) > 0:
                sell_ratio = self.determine_sell_ratio(amount)
                num_positions_to_sell = int(len(self.positions) * sell_ratio)
                for i in range(num_positions_to_sell):
                    sell_price = self.data.iloc[self.t, :]['Close']
                    buy_price = self.positions[i]
                    count = self.count[i]
                    abs_num = (sell_price - buy_price) * count
                    if abs_num > 0:
                        self.RW_p += 1
                        self.RW_p_v += abs_num
                    else:
                        self.RW_n += 1
                        self.RW_n_v += abs(abs_num)
                    reward += sell_price * count
                    self.profits += sell_price * count
                self.positions = self.positions[num_positions_to_sell:]
                self.count = self.count[num_positions_to_sell:]
                self.Act2 += 1    
        else:
            self.Act0 += 1
        
        self.t += 1
        if self.t >= len(self.data):
            self.done = True
        self.position_value = 0
        for p in self.positions:
            self.position_value += (self.data.iloc[self.t, :]['Close'] - p)
        self.history.pop(0)
        self.history.append(self.data.iloc[self.t, :]['Close'] - self.data.iloc[(self.t-1), :]['Close'])
        
        if reward > 0:
            reward = 1
        elif reward < 0:
            reward = -1
        
        return [self.position_value] + self.history, reward, self.done
    
    def determine_sell_ratio(self, signal_strength):
        thresholds = [0.2, 0.5, 0.8]
        ratios = [0.25, 0.5, 0.75]
        for i, threshold in enumerate(thresholds):
            if signal_strength < threshold:
                return ratios[i]
        return ratios[0]

def train_dqn(env, Q, epoch_num=1):
    Q_ast = copy.deepcopy(Q)
    optimizer = chainer.optimizers.Adam()
    optimizer.setup(Q)

    step_max = len(env.data)-1
    memory_size = 200
    batch_size = 20
    epsilon = 1.0
    epsilon_decrease = 1e-3
    epsilon_min = 0.1
    start_reduce_epsilon = 200
    train_freq = 10
    update_q_freq = 20
    gamma = 0.97
    show_log_freq = 1
    confidence_threshold_buy = 0.11803540036662069
    confidence_threshold_sell = 0.5689542195973996
    memory = []
    total_step = 0
    total_rewards = []
    total_losses = []
    start = time.time()
    
    for epoch in range(epoch_num):
        pobs = env.reset()
        step = 0
        done = False
        total_reward = 0
        total_loss = 0
        RandAct = 0
        NRandAct = 0
        while not done and step < step_max:
            pact = np.random.randint(3)
            amount = 0.25
            if np.random.rand() > epsilon:
                q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
                softmax_q_values = F.softmax(q_values).data
                amount = softmax_q_values.ravel()[pact]
                pact = np.random.choice(3, p=softmax_q_values.ravel())
                if pact == 2:
                    if amount < confidence_threshold_sell:
                        pact = 0
                if pact == 1:
                    if amount < confidence_threshold_buy:
                        pact = 0
                NRandAct+=1
            else:
                RandAct+=1
                if pact==0: amount = 0.5
            obs, reward, done = env.step(pact,amount)
            memory.append((pobs, pact, reward, obs, done))
            if len(memory) > memory_size:
                memory.pop(0)
            if len(memory) == memory_size:
                if total_step % train_freq == 0:
                    shuffled_memory = np.random.permutation(memory)
                    memory_idx = range(len(shuffled_memory))
                    for i in memory_idx[::batch_size]:
                        batch = np.array(shuffled_memory[i:i+batch_size])
                        b_pobs = np.array(batch[:, 0].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_pact = np.array(batch[:, 1].tolist(), dtype=np.int32)
                        b_reward = np.array(batch[:, 2].tolist(), dtype=np.int32)
                        b_obs = np.array(batch[:, 3].tolist(), dtype=np.float32).reshape(batch_size, -1)
                        b_done = np.array(batch[:, 4].tolist(), dtype=np.bool)
                        q = Q(b_pobs)
                        maxq = np.max(Q_ast(b_obs).data, axis=1)
                        target = copy.deepcopy(q.data)
                        for j in range(batch_size):
                            target[j, b_pact[j]] = b_reward[j]+gamma*maxq[j]*(not b_done[j])
                        Q.reset()
                        loss = F.mean_squared_error(q, target)
                        total_loss += loss.data
                        loss.backward()
                        optimizer.update()
                if total_step % update_q_freq == 0:
                    Q_ast = copy.deepcopy(Q)
            if epsilon > epsilon_min and total_step > start_reduce_epsilon:
                epsilon -= epsilon_decrease
            total_reward += reward
            pobs = obs
            step += 1
            total_step += 1
        total_rewards.append(total_reward)
        total_losses.append(total_loss)
        if (epoch+1) % show_log_freq == 0:
            log_reward = sum(total_rewards[((epoch+1)-show_log_freq):])/show_log_freq
            log_loss = sum(total_losses[((epoch+1)-show_log_freq):])/show_log_freq
            log_profits = env.profits
            if isinstance(env.count, list) and len(env.count) != 0:
                for i in range(len(env.positions)):
                    log_profits += env.count[i] * env.data.iloc[env.t, :]['Close']
            else:
                log_profits = env.profits
            elapsed_time = time.time()-start
            print(f"Training Epoch {epoch+1} - Profit: {log_profits}")
            start = time.time()       
    return Q, total_losses, total_rewards

def test_dqn(test_env, Q, confidence_threshold_buy=0.1, confidence_threshold_sell=0.8):
    pobs = test_env.reset()
    test_env.profits = 10000
    test_acts = []
    test_rewards = []
    estimated_total_assets = [test_env.profits]

    while not test_env.done:
        q_values = Q(np.array(pobs, dtype=np.float32).reshape(1, -1))
        softmax_q_values = F.softmax(q_values).data
        pact = np.random.choice(3, p=softmax_q_values.ravel())
        amount = softmax_q_values.ravel()[pact]
        if pact == 2 and amount < confidence_threshold_sell:
            pact = 0
        elif pact == 1 and amount < confidence_threshold_buy:
            pact = 0
        obs, reward, done = test_env.step(pact, amount)
        test_acts.append(pact)
        test_rewards.append(reward)
        pobs = obs
        stock_value = sum(c * test_env.data.iloc[test_env.t]['Close'] for c in test_env.count)
        total_assets = test_env.profits + stock_value
        estimated_total_assets.append(total_assets)

    final_profits = total_assets
    return test_acts, test_rewards, final_profits

data = pd.read_csv('C:/Users/User/Documents/RL_/Data/Stocks/SPY_Both.txt')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')

start_date_2010 = datetime.datetime(2010, 1, 1)
end_date_2019 = datetime.datetime(2019, 12, 31)
total_days_2010_2019 = (end_date_2019 - start_date_2010).days
train_days_2010_2019 = int(total_days_2010_2019 * 0.9)
test_days_2010_2019 = total_days_2010_2019 - train_days_2010_2019

test_start_date_2010_2019 = start_date_2010 + datetime.timedelta(days=train_days_2010_2019)
train_end_date_2010_2019 = test_start_date_2010_2019 - datetime.timedelta(days=1)

print("2010-2019的訓練期間:", start_date_2010.date(), "到", train_end_date_2010_2019.date())
print("2010-2019的測試期間:", test_start_date_2010_2019.date(), "到", end_date_2019.date())

print("2010-2019的訓練天數:", train_days_2010_2019)
print("2010-2019的測試天數:", test_days_2010_2019)

train = data[start_date_2010.date():train_end_date_2010_2019.date()]
test = data[test_start_date_2010_2019.date():end_date_2019.date()]
train_env = Environment1(train)
test_env = Environment1(test)

epoch_nums = range(30, 300)
final_profits = []
print('\t'.join(map(str, ['epoch', 'profit'])))
Q = Q_Network(input_size=train_env.history_t+1, hidden_size=100, output_size=3)  # 初始Q网络

# 预训练30个epoch
Q, total_losses, total_rewards = train_dqn(train_env, Q, epoch_num=29)
chainer.serializers.save_npz(f'Q_network_epoch_{29}.npz', Q)
print(f"Pre-training complete for Epoch 29")

# 从31个epoch开始继续训练和测试
for epoch_num in epoch_nums:
    Q, total_losses, total_rewards = train_dqn(train_env, Q, epoch_num=1)
    chainer.serializers.save_npz(f'Q_network_epoch_{epoch_num}.npz', Q)
    print(f"Training complete for Epoch {epoch_num}")
    
    # 进行10次测试并计算平均值
    test_profits_list = []
    for _ in range(100):
        _, _, test_profits = test_dqn(test_env, Q)
        test_profits_list.append(test_profits)
    avg_test_profits = np.mean(test_profits_list)
    
    final_profits.append(avg_test_profits)
    print(f"Epoch {epoch_num} - Average Final Profits: {avg_test_profits}")

plt.figure(figsize=(10, 6))
plt.plot(epoch_nums, final_profits, label='Average Final Profits')
plt.xlabel('Epoch Number')
plt.ylabel('Average Final Profits')
plt.title('Average Final Profits vs Epoch Number')
plt.legend()
plt.grid(True)
plt.show()
